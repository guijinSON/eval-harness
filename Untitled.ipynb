# %%
import os
import pandas as pd
for fp in os.listdir('results/c4ai-aya-expanse-8b'):
    if fp.endswith('json'):
        print(fp)
# Out:
# results_2025-03-17T06-57-37.838205.json
# results_2025-03-17T07-00-17.849120.json
# results_2025-03-17T09-09-54.475876.json

# %%
# Out:
#                                                                                            results  \
# kmmlu_pro_poc_simple-evals_technical_consultant  {'alias': 'kmmlu_pro_poc_simple-evals_technica...
# model                                                                                          NaN
# model_args                                                                                     NaN
# batch_size                                                                                     NaN
# batch_sizes                                                                                    NaN
# device                                                                                         NaN
# use_cache                                                                                      NaN
# limit                                                                                          NaN
# ...
